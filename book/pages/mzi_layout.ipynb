# %% [markdown]
# # Laying out a Mach-Zehnder Interferometer
#
# This page will walk you through the steps of laying out an MZI for fabrication. In the last tutorial we learned how to use Simphony to simulate an MZI, and now we will learn to prepare a GDS file using the SiEPIC PDK.

# %%
import gdsfactory as gf

import ubcpdk
import ubcpdk.components as uc

gf.CONF.display_type = "klayout"
# Out:
# 2024-01-25 16:04:20.032 | INFO     | gdsfactory.technology.layer_views:__init__:790 - Importing LayerViews from YAML file: '/home/parkeraa/miniconda3/envs/mp/lib/python3.11/site-packages/ubcpdk/layers.yaml'.
# 2024-01-25 16:04:21.396 | INFO     | ubcpdk:<module>:30 - Found UBCpdk '2.3.4' installed at PosixPath('/home/parkeraa/miniconda3/envs/mp/lib/python3.11/site-packages/ubcpdk')
# 2024-01-25 16:04:21.468 | INFO     | gdsfactory.technology.layer_views:__init__:790 - Importing LayerViews from YAML file: '/home/parkeraa/miniconda3/envs/mp/lib/python3.11/site-packages/gdsfactory/generic_tech/layer_views.yaml'.
# 2024-01-25 16:04:21.472 | INFO     | gdsfactory.pdk:activate:307 - 'ubcpdk' PDK is now active

# %%
c = uc.ebeam_crossing4()
c.plot()

# %%
c = uc.ebeam_bdc_te1550()
c.plot()

# %%
c = uc.ebeam_y_1550()
c.plot()

# %%
splitter = uc.ebeam_y_1550(decorator=gf.port.auto_rename_ports)
mzi = gf.components.mzi(splitter=splitter)
mzi.plot()

# %%
component_fiber_array = uc.add_fiber_array(component=mzi)
component_fiber_array.plot()

# %%
component_fiber_array.write_gds("mzi.gds")
# Out:
# 2024-01-25 16:21:50.622 | INFO     | gdsfactory.component:_write_library:1913 - Wrote to 'mzi.gds'
# PosixPath('mzi.gds')
