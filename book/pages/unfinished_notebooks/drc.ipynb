# %% [markdown]
# # Design rule checks
#
# Design rules are an essential part of a {term}`PDK`. Usually defined by the fabrication facility, they help you validate the manufacturability of your designs.
